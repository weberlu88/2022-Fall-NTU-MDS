# %% [markdown]
# ### Q2 - Tabu search

# %%
import pandas as pd
import random as rd
from itertools import combinations
import math

''' 基本變數 static '''
num_job=20 # number of jobs

j=list(range(1,num_job+1)) 
p=[10,10,13,4,9,4,8,15,7,1,9,3,15,9,11,6,5,14,18,3]
d=[50,38,49,12,20,105,73,45,6,64,15,6,92,43,78,21,15,50,150,99]
w=[10,5,1,5,10,1,5,10,5,1,5,10,10,5,1,10,5,5,1,5]

data = pd.DataFrame({
    # 'Job': j,
    'weight': w,
    "processing_time": p,
    "due_date": d,
}, index=j)
data
# Out:
#     weight  processing_time  due_date
# 1       10               10        50
# 2        5               10        38
# 3        1               13        49
# 4        5                4        12
# 5       10                9        20
# 6        1                4       105
# 7        5                8        73
# 8       10               15        45
# 9        5                7         6
# 10       1                1        64
# 11       5                9        15
# 12      10                3         6
# 13      10               15        92
# 14       5                9        43
# 15       1               11        78
# 16      10                6        21
# 17       5                5        15
# 18       5               14        50
# 19       1               18       150
# 20       5                3        99

# %%
# pd.read_excel('Instance_20.xlsx', names=['Job', 'weight', "processing_time", "due_date"],
#                                  index_col=0).to_dict('index')

# %%
class TS():
    def __init__(self, data, seed, tabu_tenure):
        # self.Path = Path
        self.seed = seed
        self.tabu_tenure = tabu_tenure
        self.instance_dict = data.to_dict('index')
        # self.instance_dict = self.input_data()
        self.Initial_solution = self.get_InitialSolution()
        self.tabu_str, self.Best_solution, self.Best_objvalue = self.TSearch()


    def input_data(self):
        '''Takes the path of the excel file of the SMTWTP instances.
        Returns a dict of jobs number as Key and weight, processing time (hours) and due date (hours) as values.
        '''
        return pd.read_excel(self.Path, names=['Job', 'weight', "processing_time", "due_date"],
                                 index_col=0).to_dict('index')

    def get_tabuestructure(self):
        '''Takes a dict (input data)
        Returns a dict of tabu attributes(pair of jobs that are swapped) as keys and [tabu_time, MoveValue]
        '''
        dict = {}
        for swap in combinations(self.instance_dict.keys(), 2):
            dict[swap] = {'tabu_time': 0, 'MoveValue': 0}
        return dict

    def get_InitialSolution(self, show=False):
        n_jobs = len(self.instance_dict) # Number of jobs
        # Producing a random schedule of jobs
        initial_solution = list(range(1, n_jobs+1))
        rd.seed(self.seed)
        rd.shuffle(initial_solution)
        if show == True:
            print("initial Random Solution: {}".format(initial_solution))
        return initial_solution

    def Objfun(self, solution, show = False):
        '''Takes a set of scheduled jobs, dict (input data)
        Return the objective function value of the solution
        '''
        dict = self.instance_dict
        t = 0   #starting time
        objfun_value = 0
        for job in solution:
            C_i = t + dict[job]["processing_time"]  # Completion time
            d_i = dict[job]["due_date"]   # due date of the job
            T_i = max(0, C_i - d_i)    #tardiness for the job
            W_i = dict[job]["weight"]  # job's weight

            objfun_value +=  W_i * T_i
            t = C_i
        if show == True:
            print("\n","="*10, "The Objective function value for {} solution schedule is: {}".format(solution ,objfun_value),"="*10)
        return objfun_value

    def SwapMove(self, solution, i ,j):
        '''Takes a list (solution)
        returns a new neighbor solution with i, j swapped
       '''
        solution = solution.copy()
        # job index in the solution:
        i_index = solution.index(i)
        j_index = solution.index(j)
        #Swap
        solution[i_index], solution[j_index] = solution[j_index], solution[i_index]
        return solution

    def TSearch(self):
        '''The implementation Tabu search algorithm with short-term memory and pair_swap as Tabu attribute.
        '''
        # Parameters:
        tenure =self.tabu_tenure
        tabu_structure = self.get_tabuestructure()  # Initialize the data structures
        best_solution = self.Initial_solution
        best_objvalue = self.Objfun(best_solution)
        current_solution = self.Initial_solution
        current_objvalue = self.Objfun(current_solution)

        print("="*30, "Short-term memory TS with Tabu Tenure: {}\nInitial Solution: {}, Initial Objvalue: {}".format(
            tenure, current_solution, current_objvalue), "="*30, sep='\n\n')
        iter = 1
        Terminate = 0
        while Terminate < 100:
            print('\n\n# iter {}  Current_Objvalue: {}, Best_Objvalue: {}'.format(iter, current_objvalue,
                                                                                    best_objvalue))
            # Searching the whole neighborhood of the current solution:
            for move in tabu_structure:
                candidate_solution = self.SwapMove(current_solution, move[0], move[1])
                candidate_objvalue = self.Objfun(candidate_solution)
                tabu_structure[move]['MoveValue'] = candidate_objvalue

            # Admissible move
            while True:
                # select the move with the lowest ObjValue in the neighborhood (minimization)
                best_move = min(tabu_structure, key =lambda x: tabu_structure[x]['MoveValue'])
                MoveValue = tabu_structure[best_move]["MoveValue"]
                tabu_time = tabu_structure[best_move]["tabu_time"]
                # Not Tabu
                if tabu_time < iter:
                    # make the move
                    current_solution = self.SwapMove(current_solution, best_move[0], best_move[1])
                    current_objvalue = self.Objfun(current_solution)
                    # Best Improving move
                    if MoveValue < best_objvalue:
                        best_solution = current_solution
                        best_objvalue = current_objvalue
                        print("   best_move: {}, Objvalue: {} => Best Improving => Admissible".format(best_move,
                                                                                                      current_objvalue))
                        Terminate = 0
                    else:
                        print("   #Termination: {}# best_move: {}, Objvalue: {} => Least non-improving => "
                              "Admissible".format(Terminate,best_move,
                                                                                                           current_objvalue))
                        Terminate += 1
                    # update tabu_time for the move
                    tabu_structure[best_move]['tabu_time'] = iter + tenure
                    iter += 1
                    break
                # If tabu
                else:
                    # Aspiration
                    if MoveValue < best_objvalue:
                        # make the move
                        current_solution = self.SwapMove(current_solution, best_move[0], best_move[1])
                        current_objvalue = self.Objfun(current_solution)
                        best_solution = current_solution
                        best_objvalue = current_objvalue
                        print("   best_move: {}, Objvalue: {} => Aspiration => Admissible".format(best_move,
                                                                                                      current_objvalue))
                        Terminate = 0
                        iter += 1
                        break
                    else:
                        tabu_structure[best_move]["MoveValue"] = float('inf')
                        print("   best_move: {}, Objvalue: {} => Tabu => Inadmissible".format(best_move,
                                                                                              current_objvalue))
                        continue
        print('='*30 , "Performed iterations: {}".format(iter), "Best found Solution: {} , Objvalue: {}".format(best_solution,best_objvalue), sep="\n")
        return tabu_structure, best_solution, best_objvalue

# %% [markdown]
# #### Run Tabu Script
# 參數調整
# - tabu_tenure = `3`
# - tabu_tenure = `5`
# - tabu_tenure = `10`
#
# 結論
# - 不同的記憶長度，得到相同的最佳解 `Best found Solution: [12, 17, 4, 16, 5, 9, 8, 1, 11, 10, 7, 13, 20, 14, 2, 18, 6, 15, 3, 19] , Objvalue: 1928`，而且禁忌搜尋法只花了 20 回合就得到這組解。雖然基因演算法只要花 12 回合就可得到最佳解，如果迭迨需要花費大量的運算，那麼基因或許比較適合，但這個情境若要追求最佳解，那麼禁忌搜尋法更適合使用，畢竟 1928 還是比 21xx 低了 1/10 的延遲加權。

# %%
tabuSearch = TS(data=data, seed = 2022, tabu_tenure=3)
# Out:
# ==============================
#
# Short-term memory TS with Tabu Tenure: 3
# Initial Solution: [5, 16, 8, 20, 4, 17, 3, 11, 1, 6, 7, 14, 12, 13, 9, 2, 19, 15, 10, 18], Initial Objvalue: 4033
#
# ==============================
#
#
# # iter 1  Current_Objvalue: 4033, Best_Objvalue: 4033
#    best_move: (3, 12), Objvalue: 3296 => Best Improving => Admissible
#
#
# # iter 2  Current_Objvalue: 3296, Best_Objvalue: 3296
#    best_move: (8, 12), Objvalue: 2906 => Best Improving => Admissible
#
#
# # iter 3  Current_Objvalue: 2906, Best_Objvalue: 2906
#    best_move: (3, 18), Objvalue: 2629 => Best Improving => Admissible
#
#
# # iter 4  Current_Objvalue: 2629, Best_Objvalue: 2629
#    best_move: (6, 9), Objvalue: 2470 => Best Improving => Admissible
#
#
# # iter 5  Current_Objvalue: 2470, Best_Objvalue: 2470
#    best_move: (5, 12), Objvalue: 2350 => Best Improving => Admissible
#
#
# # iter 6  Current_Objvalue: 2350, Best_Objvalue: 2350
#    best_move: (9, 20), Objvalue: 2260 => Best Improving => Admissible
#
#
# # iter 7  Current_Objvalue: 2260, Best_Objvalue: 2260
#    best_move: (13, 18), Objvalue: 2195 => Best Improving => Admissible
#
#
# # iter 8  Current_Objvalue: 2195, Best_Objvalue: 2195
#    best_move: (1, 11), Objvalue: 2155 => Best Improving => Admissible
#
#
# # iter 9  Current_Objvalue: 2155, Best_Objvalue: 2155
#    best_move: (9, 16), Objvalue: 2120 => Best Improving => Admissible
#
#
# # iter 10  Current_Objvalue: 2120, Best_Objvalue: 2120
#    best_move: (10, 19), Objvalue: 2085 => Best Improving => Admissible
#
#
# # iter 11  Current_Objvalue: 2085, Best_Objvalue: 2085
#    best_move: (10, 18), Objvalue: 2054 => Best Improving => Admissible
#
#
# # iter 12  Current_Objvalue: 2054, Best_Objvalue: 2054
#    best_move: (10, 20), Objvalue: 2004 => Best Improving => Admissible
#
#
# # iter 13  Current_Objvalue: 2004, Best_Objvalue: 2004
#    best_move: (4, 5), Objvalue: 1979 => Best Improving => Admissible
#
#
# # iter 14  Current_Objvalue: 1979, Best_Objvalue: 1979
#    best_move: (13, 14), Objvalue: 1964 => Best Improving => Admissible
#
#
# # iter 15  Current_Objvalue: 1964, Best_Objvalue: 1964
#    best_move: (2, 6), Objvalue: 1954 => Best Improving => Admissible
#
#
# # iter 16  Current_Objvalue: 1954, Best_Objvalue: 1954
#    best_move: (14, 20), Objvalue: 1944 => Best Improving => Admissible
#
#
# # iter 17  Current_Objvalue: 1944, Best_Objvalue: 1944
#    best_move: (6, 18), Objvalue: 1938 => Best Improving => Admissible
#
#
# # iter 18  Current_Objvalue: 1938, Best_Objvalue: 1938
#    best_move: (3, 19), Objvalue: 1933 => Best Improving => Admissible
#
#
# # iter 19  Current_Objvalue: 1933, Best_Objvalue: 1933
#    best_move: (9, 17), Objvalue: 1928 => Best Improving => Admissible
#
#
# # iter 20  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 0# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 21  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 1# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 22  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 2# best_move: (10, 11), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 23  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 11), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 3# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 24  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 4# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 25  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 5# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 26  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 6# best_move: (10, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 27  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 7# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 28  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 8# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 29  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 9# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 30  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 10# best_move: (10, 11), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 31  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 11), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 11# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 32  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 12# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 33  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 13# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 34  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 14# best_move: (10, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 35  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 15# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 36  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 16# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 37  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 17# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 38  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 18# best_move: (10, 11), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 39  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 11), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 19# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 40  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 20# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 41  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 21# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 42  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 22# best_move: (10, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 43  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 23# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 44  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 24# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 45  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 25# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 46  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 26# best_move: (10, 11), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 47  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 11), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 27# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 48  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 28# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 49  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 29# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 50  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 30# best_move: (10, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 51  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 31# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 52  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 32# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 53  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 33# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 54  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 34# best_move: (10, 11), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 55  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 11), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 35# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 56  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 36# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 57  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 37# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 58  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 38# best_move: (10, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 59  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 39# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 60  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 40# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 61  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 41# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 62  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 42# best_move: (10, 11), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 63  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 11), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 43# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 64  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 44# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 65  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 45# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 66  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 46# best_move: (10, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 67  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 47# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 68  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 48# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 69  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 49# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 70  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 50# best_move: (10, 11), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 71  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 11), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 51# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 72  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 52# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 73  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 53# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 74  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 54# best_move: (10, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 75  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 55# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 76  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 56# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 77  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 57# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 78  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 58# best_move: (10, 11), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 79  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 11), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 59# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 80  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 60# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 81  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 61# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 82  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 62# best_move: (10, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 83  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 63# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 84  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 64# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 85  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 65# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 86  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 66# best_move: (10, 11), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 87  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 11), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 67# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 88  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 68# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 89  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 69# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 90  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 70# best_move: (10, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 91  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 71# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 92  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 72# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 93  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 73# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 94  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 74# best_move: (10, 11), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 95  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 11), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 75# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 96  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 76# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 97  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 77# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 98  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 78# best_move: (10, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 99  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 79# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 100  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 80# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 101  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 81# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 102  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 82# best_move: (10, 11), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 103  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 11), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 83# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 104  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 84# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 105  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 85# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 106  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 86# best_move: (10, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 107  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 87# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 108  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 88# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 109  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 89# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 110  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 90# best_move: (10, 11), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 111  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 11), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 91# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 112  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 92# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 113  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 93# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 114  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 94# best_move: (10, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 115  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 95# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 116  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 96# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 117  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 97# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 118  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 98# best_move: (10, 11), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 119  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 11), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 99# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
# ==============================
# Performed iterations: 120
# Best found Solution: [12, 17, 4, 16, 5, 9, 8, 1, 11, 10, 7, 13, 20, 14, 2, 18, 6, 15, 3, 19] , Objvalue: 1928

# %%
tabuSearch = TS(data=data, seed = 2022, tabu_tenure=5)
# Out:
# ==============================
#
# Short-term memory TS with Tabu Tenure: 5
# Initial Solution: [5, 16, 8, 20, 4, 17, 3, 11, 1, 6, 7, 14, 12, 13, 9, 2, 19, 15, 10, 18], Initial Objvalue: 4033
#
# ==============================
#
#
# # iter 1  Current_Objvalue: 4033, Best_Objvalue: 4033
#    best_move: (3, 12), Objvalue: 3296 => Best Improving => Admissible
#
#
# # iter 2  Current_Objvalue: 3296, Best_Objvalue: 3296
#    best_move: (8, 12), Objvalue: 2906 => Best Improving => Admissible
#
#
# # iter 3  Current_Objvalue: 2906, Best_Objvalue: 2906
#    best_move: (3, 18), Objvalue: 2629 => Best Improving => Admissible
#
#
# # iter 4  Current_Objvalue: 2629, Best_Objvalue: 2629
#    best_move: (6, 9), Objvalue: 2470 => Best Improving => Admissible
#
#
# # iter 5  Current_Objvalue: 2470, Best_Objvalue: 2470
#    best_move: (5, 12), Objvalue: 2350 => Best Improving => Admissible
#
#
# # iter 6  Current_Objvalue: 2350, Best_Objvalue: 2350
#    best_move: (9, 20), Objvalue: 2260 => Best Improving => Admissible
#
#
# # iter 7  Current_Objvalue: 2260, Best_Objvalue: 2260
#    best_move: (13, 18), Objvalue: 2195 => Best Improving => Admissible
#
#
# # iter 8  Current_Objvalue: 2195, Best_Objvalue: 2195
#    best_move: (1, 11), Objvalue: 2155 => Best Improving => Admissible
#
#
# # iter 9  Current_Objvalue: 2155, Best_Objvalue: 2155
#    best_move: (9, 16), Objvalue: 2120 => Best Improving => Admissible
#
#
# # iter 10  Current_Objvalue: 2120, Best_Objvalue: 2120
#    best_move: (10, 19), Objvalue: 2085 => Best Improving => Admissible
#
#
# # iter 11  Current_Objvalue: 2085, Best_Objvalue: 2085
#    best_move: (10, 18), Objvalue: 2054 => Best Improving => Admissible
#
#
# # iter 12  Current_Objvalue: 2054, Best_Objvalue: 2054
#    best_move: (10, 20), Objvalue: 2004 => Best Improving => Admissible
#
#
# # iter 13  Current_Objvalue: 2004, Best_Objvalue: 2004
#    best_move: (4, 5), Objvalue: 1979 => Best Improving => Admissible
#
#
# # iter 14  Current_Objvalue: 1979, Best_Objvalue: 1979
#    best_move: (13, 14), Objvalue: 1964 => Best Improving => Admissible
#
#
# # iter 15  Current_Objvalue: 1964, Best_Objvalue: 1964
#    best_move: (2, 6), Objvalue: 1954 => Best Improving => Admissible
#
#
# # iter 16  Current_Objvalue: 1954, Best_Objvalue: 1954
#    best_move: (14, 20), Objvalue: 1944 => Best Improving => Admissible
#
#
# # iter 17  Current_Objvalue: 1944, Best_Objvalue: 1944
#    best_move: (6, 18), Objvalue: 1938 => Best Improving => Admissible
#
#
# # iter 18  Current_Objvalue: 1938, Best_Objvalue: 1938
#    best_move: (3, 19), Objvalue: 1933 => Best Improving => Admissible
#
#
# # iter 19  Current_Objvalue: 1933, Best_Objvalue: 1933
#    best_move: (9, 17), Objvalue: 1928 => Best Improving => Admissible
#
#
# # iter 20  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 0# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 21  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 1# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 22  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 2# best_move: (10, 11), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 23  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 11), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 3# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 24  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 4# best_move: (10, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 25  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 5# best_move: (3, 15), Objvalue: 1930 => Least non-improving => Admissible
#
#
# # iter 26  Current_Objvalue: 1930, Best_Objvalue: 1928
#    best_move: (3, 15), Objvalue: 1930 => Tabu => Inadmissible
#    #Termination: 6# best_move: (4, 17), Objvalue: 1930 => Least non-improving => Admissible
#
#
# # iter 27  Current_Objvalue: 1930, Best_Objvalue: 1928
#    best_move: (3, 15), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1930 => Tabu => Inadmissible
#    #Termination: 7# best_move: (5, 16), Objvalue: 1930 => Least non-improving => Admissible
#
#
# # iter 28  Current_Objvalue: 1930, Best_Objvalue: 1928
#    best_move: (3, 15), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1930 => Tabu => Inadmissible
#    #Termination: 8# best_move: (7, 10), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 29  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (7, 10), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 9# best_move: (11, 14), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 30  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (7, 10), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 10# best_move: (2, 14), Objvalue: 1938 => Least non-improving => Admissible
#
#
# # iter 31  Current_Objvalue: 1938, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1938 => Tabu => Inadmissible
#    #Termination: 11# best_move: (3, 15), Objvalue: 1936 => Least non-improving => Admissible
#
#
# # iter 32  Current_Objvalue: 1936, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1936 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1936 => Tabu => Inadmissible
#    #Termination: 12# best_move: (4, 17), Objvalue: 1936 => Least non-improving => Admissible
#
#
# # iter 33  Current_Objvalue: 1936, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1936 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1936 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1936 => Tabu => Inadmissible
#    #Termination: 13# best_move: (5, 16), Objvalue: 1936 => Least non-improving => Admissible
#
#
# # iter 34  Current_Objvalue: 1936, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1936 => Tabu => Inadmissible
#    #Termination: 14# best_move: (7, 10), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 35  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 15# best_move: (10, 11), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 36  Current_Objvalue: 1933, Best_Objvalue: 1928
#    #Termination: 16# best_move: (2, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 37  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 11), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 17# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 38  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 18# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 39  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 19# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 40  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 20# best_move: (10, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 41  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 21# best_move: (3, 15), Objvalue: 1930 => Least non-improving => Admissible
#
#
# # iter 42  Current_Objvalue: 1930, Best_Objvalue: 1928
#    best_move: (3, 15), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1930 => Tabu => Inadmissible
#    #Termination: 22# best_move: (7, 10), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 43  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (7, 10), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 23# best_move: (11, 14), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 44  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (7, 10), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 24# best_move: (4, 17), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 45  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (7, 10), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 25# best_move: (5, 16), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 46  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (7, 10), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 26# best_move: (2, 14), Objvalue: 1938 => Least non-improving => Admissible
#
#
# # iter 47  Current_Objvalue: 1938, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1938 => Tabu => Inadmissible
#    #Termination: 27# best_move: (3, 15), Objvalue: 1936 => Least non-improving => Admissible
#
#
# # iter 48  Current_Objvalue: 1936, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1936 => Tabu => Inadmissible
#    #Termination: 28# best_move: (7, 10), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 49  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 29# best_move: (10, 11), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 50  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 30# best_move: (4, 17), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 51  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 31# best_move: (5, 16), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 52  Current_Objvalue: 1933, Best_Objvalue: 1928
#    #Termination: 32# best_move: (2, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 53  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 11), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 33# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 54  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 34# best_move: (10, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 55  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 35# best_move: (3, 15), Objvalue: 1930 => Least non-improving => Admissible
#
#
# # iter 56  Current_Objvalue: 1930, Best_Objvalue: 1928
#    best_move: (3, 15), Objvalue: 1930 => Tabu => Inadmissible
#    #Termination: 36# best_move: (4, 17), Objvalue: 1930 => Least non-improving => Admissible
#
#
# # iter 57  Current_Objvalue: 1930, Best_Objvalue: 1928
#    best_move: (3, 15), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1930 => Tabu => Inadmissible
#    #Termination: 37# best_move: (5, 16), Objvalue: 1930 => Least non-improving => Admissible
#
#
# # iter 58  Current_Objvalue: 1930, Best_Objvalue: 1928
#    best_move: (3, 15), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1930 => Tabu => Inadmissible
#    #Termination: 38# best_move: (7, 10), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 59  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (7, 10), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 39# best_move: (11, 14), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 60  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (7, 10), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 40# best_move: (2, 14), Objvalue: 1938 => Least non-improving => Admissible
#
#
# # iter 61  Current_Objvalue: 1938, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1938 => Tabu => Inadmissible
#    #Termination: 41# best_move: (3, 15), Objvalue: 1936 => Least non-improving => Admissible
#
#
# # iter 62  Current_Objvalue: 1936, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1936 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1936 => Tabu => Inadmissible
#    #Termination: 42# best_move: (4, 17), Objvalue: 1936 => Least non-improving => Admissible
#
#
# # iter 63  Current_Objvalue: 1936, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1936 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1936 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1936 => Tabu => Inadmissible
#    #Termination: 43# best_move: (5, 16), Objvalue: 1936 => Least non-improving => Admissible
#
#
# # iter 64  Current_Objvalue: 1936, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1936 => Tabu => Inadmissible
#    #Termination: 44# best_move: (7, 10), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 65  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 45# best_move: (10, 11), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 66  Current_Objvalue: 1933, Best_Objvalue: 1928
#    #Termination: 46# best_move: (2, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 67  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 11), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 47# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 68  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 48# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 69  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 49# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 70  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 50# best_move: (10, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 71  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 51# best_move: (3, 15), Objvalue: 1930 => Least non-improving => Admissible
#
#
# # iter 72  Current_Objvalue: 1930, Best_Objvalue: 1928
#    best_move: (3, 15), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1930 => Tabu => Inadmissible
#    #Termination: 52# best_move: (7, 10), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 73  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (7, 10), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 53# best_move: (11, 14), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 74  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (7, 10), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 54# best_move: (4, 17), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 75  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (7, 10), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 55# best_move: (5, 16), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 76  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (7, 10), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 56# best_move: (2, 14), Objvalue: 1938 => Least non-improving => Admissible
#
#
# # iter 77  Current_Objvalue: 1938, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1938 => Tabu => Inadmissible
#    #Termination: 57# best_move: (3, 15), Objvalue: 1936 => Least non-improving => Admissible
#
#
# # iter 78  Current_Objvalue: 1936, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1936 => Tabu => Inadmissible
#    #Termination: 58# best_move: (7, 10), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 79  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 59# best_move: (10, 11), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 80  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 60# best_move: (4, 17), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 81  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 61# best_move: (5, 16), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 82  Current_Objvalue: 1933, Best_Objvalue: 1928
#    #Termination: 62# best_move: (2, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 83  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 11), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 63# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 84  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 64# best_move: (10, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 85  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 65# best_move: (3, 15), Objvalue: 1930 => Least non-improving => Admissible
#
#
# # iter 86  Current_Objvalue: 1930, Best_Objvalue: 1928
#    best_move: (3, 15), Objvalue: 1930 => Tabu => Inadmissible
#    #Termination: 66# best_move: (4, 17), Objvalue: 1930 => Least non-improving => Admissible
#
#
# # iter 87  Current_Objvalue: 1930, Best_Objvalue: 1928
#    best_move: (3, 15), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1930 => Tabu => Inadmissible
#    #Termination: 67# best_move: (5, 16), Objvalue: 1930 => Least non-improving => Admissible
#
#
# # iter 88  Current_Objvalue: 1930, Best_Objvalue: 1928
#    best_move: (3, 15), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1930 => Tabu => Inadmissible
#    #Termination: 68# best_move: (7, 10), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 89  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (7, 10), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 69# best_move: (11, 14), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 90  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (7, 10), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 70# best_move: (2, 14), Objvalue: 1938 => Least non-improving => Admissible
#
#
# # iter 91  Current_Objvalue: 1938, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1938 => Tabu => Inadmissible
#    #Termination: 71# best_move: (3, 15), Objvalue: 1936 => Least non-improving => Admissible
#
#
# # iter 92  Current_Objvalue: 1936, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1936 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1936 => Tabu => Inadmissible
#    #Termination: 72# best_move: (4, 17), Objvalue: 1936 => Least non-improving => Admissible
#
#
# # iter 93  Current_Objvalue: 1936, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1936 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1936 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1936 => Tabu => Inadmissible
#    #Termination: 73# best_move: (5, 16), Objvalue: 1936 => Least non-improving => Admissible
#
#
# # iter 94  Current_Objvalue: 1936, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1936 => Tabu => Inadmissible
#    #Termination: 74# best_move: (7, 10), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 95  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 75# best_move: (10, 11), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 96  Current_Objvalue: 1933, Best_Objvalue: 1928
#    #Termination: 76# best_move: (2, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 97  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 11), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 77# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 98  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 78# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 99  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 79# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 100  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 80# best_move: (10, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 101  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 81# best_move: (3, 15), Objvalue: 1930 => Least non-improving => Admissible
#
#
# # iter 102  Current_Objvalue: 1930, Best_Objvalue: 1928
#    best_move: (3, 15), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1930 => Tabu => Inadmissible
#    #Termination: 82# best_move: (7, 10), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 103  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (7, 10), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 83# best_move: (11, 14), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 104  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (7, 10), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 84# best_move: (4, 17), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 105  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (7, 10), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 85# best_move: (5, 16), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 106  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (7, 10), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 86# best_move: (2, 14), Objvalue: 1938 => Least non-improving => Admissible
#
#
# # iter 107  Current_Objvalue: 1938, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1938 => Tabu => Inadmissible
#    #Termination: 87# best_move: (3, 15), Objvalue: 1936 => Least non-improving => Admissible
#
#
# # iter 108  Current_Objvalue: 1936, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1936 => Tabu => Inadmissible
#    #Termination: 88# best_move: (7, 10), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 109  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 89# best_move: (10, 11), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 110  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 90# best_move: (4, 17), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 111  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (2, 14), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 91# best_move: (5, 16), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 112  Current_Objvalue: 1933, Best_Objvalue: 1928
#    #Termination: 92# best_move: (2, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 113  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 11), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 93# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 114  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 94# best_move: (10, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 115  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 95# best_move: (3, 15), Objvalue: 1930 => Least non-improving => Admissible
#
#
# # iter 116  Current_Objvalue: 1930, Best_Objvalue: 1928
#    best_move: (3, 15), Objvalue: 1930 => Tabu => Inadmissible
#    #Termination: 96# best_move: (4, 17), Objvalue: 1930 => Least non-improving => Admissible
#
#
# # iter 117  Current_Objvalue: 1930, Best_Objvalue: 1928
#    best_move: (3, 15), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1930 => Tabu => Inadmissible
#    #Termination: 97# best_move: (5, 16), Objvalue: 1930 => Least non-improving => Admissible
#
#
# # iter 118  Current_Objvalue: 1930, Best_Objvalue: 1928
#    best_move: (3, 15), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1930 => Tabu => Inadmissible
#    #Termination: 98# best_move: (7, 10), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 119  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (7, 10), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 99# best_move: (11, 14), Objvalue: 1933 => Least non-improving => Admissible
# ==============================
# Performed iterations: 120
# Best found Solution: [12, 17, 4, 16, 5, 9, 8, 1, 11, 10, 7, 13, 20, 14, 2, 18, 6, 15, 3, 19] , Objvalue: 1928

# %%
tabuSearch = TS(data=data, seed = 2022, tabu_tenure=10)
# Out:
# ==============================
#
# Short-term memory TS with Tabu Tenure: 10
# Initial Solution: [5, 16, 8, 20, 4, 17, 3, 11, 1, 6, 7, 14, 12, 13, 9, 2, 19, 15, 10, 18], Initial Objvalue: 4033
#
# ==============================
#
#
# # iter 1  Current_Objvalue: 4033, Best_Objvalue: 4033
#    best_move: (3, 12), Objvalue: 3296 => Best Improving => Admissible
#
#
# # iter 2  Current_Objvalue: 3296, Best_Objvalue: 3296
#    best_move: (8, 12), Objvalue: 2906 => Best Improving => Admissible
#
#
# # iter 3  Current_Objvalue: 2906, Best_Objvalue: 2906
#    best_move: (3, 18), Objvalue: 2629 => Best Improving => Admissible
#
#
# # iter 4  Current_Objvalue: 2629, Best_Objvalue: 2629
#    best_move: (6, 9), Objvalue: 2470 => Best Improving => Admissible
#
#
# # iter 5  Current_Objvalue: 2470, Best_Objvalue: 2470
#    best_move: (5, 12), Objvalue: 2350 => Best Improving => Admissible
#
#
# # iter 6  Current_Objvalue: 2350, Best_Objvalue: 2350
#    best_move: (9, 20), Objvalue: 2260 => Best Improving => Admissible
#
#
# # iter 7  Current_Objvalue: 2260, Best_Objvalue: 2260
#    best_move: (13, 18), Objvalue: 2195 => Best Improving => Admissible
#
#
# # iter 8  Current_Objvalue: 2195, Best_Objvalue: 2195
#    best_move: (1, 11), Objvalue: 2155 => Best Improving => Admissible
#
#
# # iter 9  Current_Objvalue: 2155, Best_Objvalue: 2155
#    best_move: (9, 16), Objvalue: 2120 => Best Improving => Admissible
#
#
# # iter 10  Current_Objvalue: 2120, Best_Objvalue: 2120
#    best_move: (10, 19), Objvalue: 2085 => Best Improving => Admissible
#
#
# # iter 11  Current_Objvalue: 2085, Best_Objvalue: 2085
#    best_move: (10, 18), Objvalue: 2054 => Best Improving => Admissible
#
#
# # iter 12  Current_Objvalue: 2054, Best_Objvalue: 2054
#    best_move: (10, 20), Objvalue: 2004 => Best Improving => Admissible
#
#
# # iter 13  Current_Objvalue: 2004, Best_Objvalue: 2004
#    best_move: (4, 5), Objvalue: 1979 => Best Improving => Admissible
#
#
# # iter 14  Current_Objvalue: 1979, Best_Objvalue: 1979
#    best_move: (13, 14), Objvalue: 1964 => Best Improving => Admissible
#
#
# # iter 15  Current_Objvalue: 1964, Best_Objvalue: 1964
#    best_move: (2, 6), Objvalue: 1954 => Best Improving => Admissible
#
#
# # iter 16  Current_Objvalue: 1954, Best_Objvalue: 1954
#    best_move: (14, 20), Objvalue: 1944 => Best Improving => Admissible
#
#
# # iter 17  Current_Objvalue: 1944, Best_Objvalue: 1944
#    best_move: (6, 18), Objvalue: 1938 => Best Improving => Admissible
#
#
# # iter 18  Current_Objvalue: 1938, Best_Objvalue: 1938
#    best_move: (3, 19), Objvalue: 1933 => Best Improving => Admissible
#
#
# # iter 19  Current_Objvalue: 1933, Best_Objvalue: 1933
#    best_move: (9, 17), Objvalue: 1928 => Best Improving => Admissible
#
#
# # iter 20  Current_Objvalue: 1928, Best_Objvalue: 1928
#    #Termination: 0# best_move: (4, 17), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 21  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 1# best_move: (5, 16), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 22  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 2# best_move: (10, 11), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 23  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 11), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 3# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 24  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 4# best_move: (10, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 25  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 5# best_move: (3, 15), Objvalue: 1930 => Least non-improving => Admissible
#
#
# # iter 26  Current_Objvalue: 1930, Best_Objvalue: 1928
#    best_move: (3, 15), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1930 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1930 => Tabu => Inadmissible
#    #Termination: 6# best_move: (7, 10), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 27  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (7, 10), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 7# best_move: (2, 11), Objvalue: 1938 => Least non-improving => Admissible
#
#
# # iter 28  Current_Objvalue: 1938, Best_Objvalue: 1928
#    best_move: (2, 11), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1938 => Tabu => Inadmissible
#    #Termination: 8# best_move: (8, 14), Objvalue: 1943 => Least non-improving => Admissible
#
#
# # iter 29  Current_Objvalue: 1943, Best_Objvalue: 1928
#    best_move: (2, 11), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (8, 14), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1943 => Tabu => Inadmissible
#    #Termination: 9# best_move: (6, 18), Objvalue: 1949 => Least non-improving => Admissible
#
#
# # iter 30  Current_Objvalue: 1949, Best_Objvalue: 1928
#    best_move: (6, 18), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (2, 11), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (8, 14), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1949 => Tabu => Inadmissible
#    #Termination: 10# best_move: (15, 19), Objvalue: 1956 => Least non-improving => Admissible
#
#
# # iter 31  Current_Objvalue: 1956, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (2, 11), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (8, 14), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1956 => Tabu => Inadmissible
#    #Termination: 11# best_move: (4, 17), Objvalue: 1956 => Least non-improving => Admissible
#
#
# # iter 32  Current_Objvalue: 1956, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (2, 11), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (8, 14), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1956 => Tabu => Inadmissible
#    #Termination: 12# best_move: (5, 16), Objvalue: 1956 => Least non-improving => Admissible
#
#
# # iter 33  Current_Objvalue: 1956, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (2, 11), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (8, 14), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1956 => Tabu => Inadmissible
#    #Termination: 13# best_move: (3, 19), Objvalue: 1961 => Least non-improving => Admissible
#
#
# # iter 34  Current_Objvalue: 1961, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (2, 11), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (3, 19), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (8, 14), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1961 => Tabu => Inadmissible
#    #Termination: 14# best_move: (11, 14), Objvalue: 1961 => Least non-improving => Admissible
#
#
# # iter 35  Current_Objvalue: 1961, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1961 => Tabu => Inadmissible
#    #Termination: 15# best_move: (2, 14), Objvalue: 1956 => Least non-improving => Admissible
#
#
# # iter 36  Current_Objvalue: 1956, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (3, 19), Objvalue: 1956 => Tabu => Inadmissible
#    #Termination: 16# best_move: (8, 11), Objvalue: 1951 => Least non-improving => Admissible
#
#
# # iter 37  Current_Objvalue: 1951, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1951 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1951 => Tabu => Inadmissible
#    best_move: (3, 19), Objvalue: 1951 => Tabu => Inadmissible
#    #Termination: 17# best_move: (7, 10), Objvalue: 1948 => Least non-improving => Admissible
#
#
# # iter 38  Current_Objvalue: 1948, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1948 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1948 => Tabu => Inadmissible
#    best_move: (3, 19), Objvalue: 1948 => Tabu => Inadmissible
#    #Termination: 18# best_move: (3, 15), Objvalue: 1946 => Least non-improving => Admissible
#
#
# # iter 39  Current_Objvalue: 1946, Best_Objvalue: 1928
#    best_move: (3, 19), Objvalue: 1946 => Tabu => Inadmissible
#    best_move: (15, 19), Objvalue: 1946 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1946 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1946 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1946 => Tabu => Inadmissible
#    #Termination: 19# best_move: (10, 11), Objvalue: 1946 => Least non-improving => Admissible
#
#
# # iter 40  Current_Objvalue: 1946, Best_Objvalue: 1928
#    best_move: (3, 19), Objvalue: 1946 => Tabu => Inadmissible
#    best_move: (15, 19), Objvalue: 1946 => Tabu => Inadmissible
#    #Termination: 20# best_move: (6, 18), Objvalue: 1940 => Least non-improving => Admissible
#
#
# # iter 41  Current_Objvalue: 1940, Best_Objvalue: 1928
#    best_move: (3, 19), Objvalue: 1940 => Tabu => Inadmissible
#    #Termination: 21# best_move: (15, 19), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 42  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (3, 19), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 22# best_move: (4, 17), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 43  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (3, 19), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 23# best_move: (5, 16), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 44  Current_Objvalue: 1933, Best_Objvalue: 1928
#    #Termination: 24# best_move: (3, 19), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 45  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 11), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 25# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 46  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 26# best_move: (10, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 47  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 27# best_move: (2, 11), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 48  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (2, 11), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 28# best_move: (7, 10), Objvalue: 1936 => Least non-improving => Admissible
#
#
# # iter 49  Current_Objvalue: 1936, Best_Objvalue: 1928
#    best_move: (2, 11), Objvalue: 1936 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1936 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1936 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1936 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1936 => Tabu => Inadmissible
#    #Termination: 29# best_move: (3, 15), Objvalue: 1938 => Least non-improving => Admissible
#
#
# # iter 50  Current_Objvalue: 1938, Best_Objvalue: 1928
#    best_move: (2, 11), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1938 => Tabu => Inadmissible
#    #Termination: 30# best_move: (8, 14), Objvalue: 1943 => Least non-improving => Admissible
#
#
# # iter 51  Current_Objvalue: 1943, Best_Objvalue: 1928
#    best_move: (2, 11), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (8, 14), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1943 => Tabu => Inadmissible
#    #Termination: 31# best_move: (6, 18), Objvalue: 1949 => Least non-improving => Admissible
#
#
# # iter 52  Current_Objvalue: 1949, Best_Objvalue: 1928
#    best_move: (6, 18), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (2, 11), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (8, 14), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1949 => Tabu => Inadmissible
#    #Termination: 32# best_move: (15, 19), Objvalue: 1956 => Least non-improving => Admissible
#
#
# # iter 53  Current_Objvalue: 1956, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (2, 11), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (8, 14), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1956 => Tabu => Inadmissible
#    #Termination: 33# best_move: (4, 17), Objvalue: 1956 => Least non-improving => Admissible
#
#
# # iter 54  Current_Objvalue: 1956, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (2, 11), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (8, 14), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1956 => Tabu => Inadmissible
#    #Termination: 34# best_move: (5, 16), Objvalue: 1956 => Least non-improving => Admissible
#
#
# # iter 55  Current_Objvalue: 1956, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (2, 11), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (8, 14), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1956 => Tabu => Inadmissible
#    #Termination: 35# best_move: (3, 19), Objvalue: 1961 => Least non-improving => Admissible
#
#
# # iter 56  Current_Objvalue: 1961, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (2, 11), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (3, 19), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (8, 14), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1961 => Tabu => Inadmissible
#    #Termination: 36# best_move: (11, 14), Objvalue: 1961 => Least non-improving => Admissible
#
#
# # iter 57  Current_Objvalue: 1961, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1961 => Tabu => Inadmissible
#    #Termination: 37# best_move: (2, 14), Objvalue: 1956 => Least non-improving => Admissible
#
#
# # iter 58  Current_Objvalue: 1956, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (3, 19), Objvalue: 1956 => Tabu => Inadmissible
#    #Termination: 38# best_move: (8, 11), Objvalue: 1951 => Least non-improving => Admissible
#
#
# # iter 59  Current_Objvalue: 1951, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1951 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1951 => Tabu => Inadmissible
#    best_move: (3, 19), Objvalue: 1951 => Tabu => Inadmissible
#    #Termination: 39# best_move: (7, 10), Objvalue: 1948 => Least non-improving => Admissible
#
#
# # iter 60  Current_Objvalue: 1948, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1948 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1948 => Tabu => Inadmissible
#    best_move: (3, 19), Objvalue: 1948 => Tabu => Inadmissible
#    #Termination: 40# best_move: (3, 15), Objvalue: 1946 => Least non-improving => Admissible
#
#
# # iter 61  Current_Objvalue: 1946, Best_Objvalue: 1928
#    best_move: (3, 19), Objvalue: 1946 => Tabu => Inadmissible
#    best_move: (15, 19), Objvalue: 1946 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1946 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1946 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1946 => Tabu => Inadmissible
#    #Termination: 41# best_move: (10, 11), Objvalue: 1946 => Least non-improving => Admissible
#
#
# # iter 62  Current_Objvalue: 1946, Best_Objvalue: 1928
#    best_move: (3, 19), Objvalue: 1946 => Tabu => Inadmissible
#    best_move: (15, 19), Objvalue: 1946 => Tabu => Inadmissible
#    #Termination: 42# best_move: (6, 18), Objvalue: 1940 => Least non-improving => Admissible
#
#
# # iter 63  Current_Objvalue: 1940, Best_Objvalue: 1928
#    best_move: (3, 19), Objvalue: 1940 => Tabu => Inadmissible
#    #Termination: 43# best_move: (15, 19), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 64  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (3, 19), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 44# best_move: (4, 17), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 65  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (3, 19), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 45# best_move: (5, 16), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 66  Current_Objvalue: 1933, Best_Objvalue: 1928
#    #Termination: 46# best_move: (3, 19), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 67  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 11), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 47# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 68  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 48# best_move: (10, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 69  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 49# best_move: (2, 11), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 70  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (2, 11), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 50# best_move: (7, 10), Objvalue: 1936 => Least non-improving => Admissible
#
#
# # iter 71  Current_Objvalue: 1936, Best_Objvalue: 1928
#    best_move: (2, 11), Objvalue: 1936 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1936 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1936 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1936 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1936 => Tabu => Inadmissible
#    #Termination: 51# best_move: (3, 15), Objvalue: 1938 => Least non-improving => Admissible
#
#
# # iter 72  Current_Objvalue: 1938, Best_Objvalue: 1928
#    best_move: (2, 11), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1938 => Tabu => Inadmissible
#    #Termination: 52# best_move: (8, 14), Objvalue: 1943 => Least non-improving => Admissible
#
#
# # iter 73  Current_Objvalue: 1943, Best_Objvalue: 1928
#    best_move: (2, 11), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (8, 14), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1943 => Tabu => Inadmissible
#    #Termination: 53# best_move: (6, 18), Objvalue: 1949 => Least non-improving => Admissible
#
#
# # iter 74  Current_Objvalue: 1949, Best_Objvalue: 1928
#    best_move: (6, 18), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (2, 11), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (8, 14), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1949 => Tabu => Inadmissible
#    #Termination: 54# best_move: (15, 19), Objvalue: 1956 => Least non-improving => Admissible
#
#
# # iter 75  Current_Objvalue: 1956, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (2, 11), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (8, 14), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1956 => Tabu => Inadmissible
#    #Termination: 55# best_move: (4, 17), Objvalue: 1956 => Least non-improving => Admissible
#
#
# # iter 76  Current_Objvalue: 1956, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (2, 11), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (8, 14), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1956 => Tabu => Inadmissible
#    #Termination: 56# best_move: (5, 16), Objvalue: 1956 => Least non-improving => Admissible
#
#
# # iter 77  Current_Objvalue: 1956, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (2, 11), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (8, 14), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1956 => Tabu => Inadmissible
#    #Termination: 57# best_move: (3, 19), Objvalue: 1961 => Least non-improving => Admissible
#
#
# # iter 78  Current_Objvalue: 1961, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (2, 11), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (3, 19), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (8, 14), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1961 => Tabu => Inadmissible
#    #Termination: 58# best_move: (11, 14), Objvalue: 1961 => Least non-improving => Admissible
#
#
# # iter 79  Current_Objvalue: 1961, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1961 => Tabu => Inadmissible
#    #Termination: 59# best_move: (2, 14), Objvalue: 1956 => Least non-improving => Admissible
#
#
# # iter 80  Current_Objvalue: 1956, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (3, 19), Objvalue: 1956 => Tabu => Inadmissible
#    #Termination: 60# best_move: (8, 11), Objvalue: 1951 => Least non-improving => Admissible
#
#
# # iter 81  Current_Objvalue: 1951, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1951 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1951 => Tabu => Inadmissible
#    best_move: (3, 19), Objvalue: 1951 => Tabu => Inadmissible
#    #Termination: 61# best_move: (7, 10), Objvalue: 1948 => Least non-improving => Admissible
#
#
# # iter 82  Current_Objvalue: 1948, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1948 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1948 => Tabu => Inadmissible
#    best_move: (3, 19), Objvalue: 1948 => Tabu => Inadmissible
#    #Termination: 62# best_move: (3, 15), Objvalue: 1946 => Least non-improving => Admissible
#
#
# # iter 83  Current_Objvalue: 1946, Best_Objvalue: 1928
#    best_move: (3, 19), Objvalue: 1946 => Tabu => Inadmissible
#    best_move: (15, 19), Objvalue: 1946 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1946 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1946 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1946 => Tabu => Inadmissible
#    #Termination: 63# best_move: (10, 11), Objvalue: 1946 => Least non-improving => Admissible
#
#
# # iter 84  Current_Objvalue: 1946, Best_Objvalue: 1928
#    best_move: (3, 19), Objvalue: 1946 => Tabu => Inadmissible
#    best_move: (15, 19), Objvalue: 1946 => Tabu => Inadmissible
#    #Termination: 64# best_move: (6, 18), Objvalue: 1940 => Least non-improving => Admissible
#
#
# # iter 85  Current_Objvalue: 1940, Best_Objvalue: 1928
#    best_move: (3, 19), Objvalue: 1940 => Tabu => Inadmissible
#    #Termination: 65# best_move: (15, 19), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 86  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (3, 19), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 66# best_move: (4, 17), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 87  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (3, 19), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 67# best_move: (5, 16), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 88  Current_Objvalue: 1933, Best_Objvalue: 1928
#    #Termination: 68# best_move: (3, 19), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 89  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 11), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 69# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 90  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 70# best_move: (10, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 91  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 71# best_move: (2, 11), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 92  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (2, 11), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 72# best_move: (7, 10), Objvalue: 1936 => Least non-improving => Admissible
#
#
# # iter 93  Current_Objvalue: 1936, Best_Objvalue: 1928
#    best_move: (2, 11), Objvalue: 1936 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1936 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1936 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1936 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1936 => Tabu => Inadmissible
#    #Termination: 73# best_move: (3, 15), Objvalue: 1938 => Least non-improving => Admissible
#
#
# # iter 94  Current_Objvalue: 1938, Best_Objvalue: 1928
#    best_move: (2, 11), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1938 => Tabu => Inadmissible
#    #Termination: 74# best_move: (8, 14), Objvalue: 1943 => Least non-improving => Admissible
#
#
# # iter 95  Current_Objvalue: 1943, Best_Objvalue: 1928
#    best_move: (2, 11), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (8, 14), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1943 => Tabu => Inadmissible
#    #Termination: 75# best_move: (6, 18), Objvalue: 1949 => Least non-improving => Admissible
#
#
# # iter 96  Current_Objvalue: 1949, Best_Objvalue: 1928
#    best_move: (6, 18), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (2, 11), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (8, 14), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1949 => Tabu => Inadmissible
#    #Termination: 76# best_move: (15, 19), Objvalue: 1956 => Least non-improving => Admissible
#
#
# # iter 97  Current_Objvalue: 1956, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (2, 11), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (8, 14), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1956 => Tabu => Inadmissible
#    #Termination: 77# best_move: (4, 17), Objvalue: 1956 => Least non-improving => Admissible
#
#
# # iter 98  Current_Objvalue: 1956, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (2, 11), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (8, 14), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1956 => Tabu => Inadmissible
#    #Termination: 78# best_move: (5, 16), Objvalue: 1956 => Least non-improving => Admissible
#
#
# # iter 99  Current_Objvalue: 1956, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (2, 11), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (8, 14), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1956 => Tabu => Inadmissible
#    #Termination: 79# best_move: (3, 19), Objvalue: 1961 => Least non-improving => Admissible
#
#
# # iter 100  Current_Objvalue: 1961, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (2, 11), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (3, 19), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (8, 14), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1961 => Tabu => Inadmissible
#    #Termination: 80# best_move: (11, 14), Objvalue: 1961 => Least non-improving => Admissible
#
#
# # iter 101  Current_Objvalue: 1961, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1961 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1961 => Tabu => Inadmissible
#    #Termination: 81# best_move: (2, 14), Objvalue: 1956 => Least non-improving => Admissible
#
#
# # iter 102  Current_Objvalue: 1956, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (3, 19), Objvalue: 1956 => Tabu => Inadmissible
#    #Termination: 82# best_move: (8, 11), Objvalue: 1951 => Least non-improving => Admissible
#
#
# # iter 103  Current_Objvalue: 1951, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1951 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1951 => Tabu => Inadmissible
#    best_move: (3, 19), Objvalue: 1951 => Tabu => Inadmissible
#    #Termination: 83# best_move: (7, 10), Objvalue: 1948 => Least non-improving => Admissible
#
#
# # iter 104  Current_Objvalue: 1948, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1948 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1948 => Tabu => Inadmissible
#    best_move: (3, 19), Objvalue: 1948 => Tabu => Inadmissible
#    #Termination: 84# best_move: (3, 15), Objvalue: 1946 => Least non-improving => Admissible
#
#
# # iter 105  Current_Objvalue: 1946, Best_Objvalue: 1928
#    best_move: (3, 19), Objvalue: 1946 => Tabu => Inadmissible
#    best_move: (15, 19), Objvalue: 1946 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1946 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1946 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1946 => Tabu => Inadmissible
#    #Termination: 85# best_move: (10, 11), Objvalue: 1946 => Least non-improving => Admissible
#
#
# # iter 106  Current_Objvalue: 1946, Best_Objvalue: 1928
#    best_move: (3, 19), Objvalue: 1946 => Tabu => Inadmissible
#    best_move: (15, 19), Objvalue: 1946 => Tabu => Inadmissible
#    #Termination: 86# best_move: (6, 18), Objvalue: 1940 => Least non-improving => Admissible
#
#
# # iter 107  Current_Objvalue: 1940, Best_Objvalue: 1928
#    best_move: (3, 19), Objvalue: 1940 => Tabu => Inadmissible
#    #Termination: 87# best_move: (15, 19), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 108  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (3, 19), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 88# best_move: (4, 17), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 109  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (3, 19), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 89# best_move: (5, 16), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 110  Current_Objvalue: 1933, Best_Objvalue: 1928
#    #Termination: 90# best_move: (3, 19), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 111  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 11), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 91# best_move: (11, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 112  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 92# best_move: (10, 14), Objvalue: 1928 => Least non-improving => Admissible
#
#
# # iter 113  Current_Objvalue: 1928, Best_Objvalue: 1928
#    best_move: (4, 17), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1928 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1928 => Tabu => Inadmissible
#    #Termination: 93# best_move: (2, 11), Objvalue: 1933 => Least non-improving => Admissible
#
#
# # iter 114  Current_Objvalue: 1933, Best_Objvalue: 1928
#    best_move: (2, 11), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (10, 14), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1933 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1933 => Tabu => Inadmissible
#    #Termination: 94# best_move: (7, 10), Objvalue: 1936 => Least non-improving => Admissible
#
#
# # iter 115  Current_Objvalue: 1936, Best_Objvalue: 1928
#    best_move: (2, 11), Objvalue: 1936 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1936 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1936 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1936 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1936 => Tabu => Inadmissible
#    #Termination: 95# best_move: (3, 15), Objvalue: 1938 => Least non-improving => Admissible
#
#
# # iter 116  Current_Objvalue: 1938, Best_Objvalue: 1928
#    best_move: (2, 11), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1938 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1938 => Tabu => Inadmissible
#    #Termination: 96# best_move: (8, 14), Objvalue: 1943 => Least non-improving => Admissible
#
#
# # iter 117  Current_Objvalue: 1943, Best_Objvalue: 1928
#    best_move: (2, 11), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (8, 14), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1943 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1943 => Tabu => Inadmissible
#    #Termination: 97# best_move: (6, 18), Objvalue: 1949 => Least non-improving => Admissible
#
#
# # iter 118  Current_Objvalue: 1949, Best_Objvalue: 1928
#    best_move: (6, 18), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (2, 11), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (8, 14), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (4, 17), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (5, 16), Objvalue: 1949 => Tabu => Inadmissible
#    best_move: (11, 14), Objvalue: 1949 => Tabu => Inadmissible
#    #Termination: 98# best_move: (15, 19), Objvalue: 1956 => Least non-improving => Admissible
#
#
# # iter 119  Current_Objvalue: 1956, Best_Objvalue: 1928
#    best_move: (15, 19), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (6, 18), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (2, 11), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (8, 14), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (3, 15), Objvalue: 1956 => Tabu => Inadmissible
#    best_move: (7, 10), Objvalue: 1956 => Tabu => Inadmissible
#    #Termination: 99# best_move: (4, 17), Objvalue: 1956 => Least non-improving => Admissible
# ==============================
# Performed iterations: 120
# Best found Solution: [12, 17, 4, 16, 5, 9, 8, 1, 11, 10, 7, 13, 20, 14, 2, 18, 6, 15, 3, 19] , Objvalue: 1928
